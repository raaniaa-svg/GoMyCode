# %%
import pandas as pd
df=pd.read_csv("titanic-passengers.csv",sep=';')
df.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000    NaN        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542    NaN        S
# 3  female  29.0      0      4      349909  21.0750    NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S
#    PassengerId Survived  Pclass                                         Name  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].fillna(df['Age'].mode(), inplace=True)
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
print(df['Age'].value_counts())
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 19.00    25
#          ..
# 80.00     1
# 36.50     1
# 55.50     1
# 14.50     1
# 0.42      1
# Name: Age, Length: 88, dtype: int64
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 19.00    25
#          ..
# 80.00     1
# 36.50     1
# 55.50     1
# 14.50     1
# 0.42      1
# Name: Age, Length: 88, dtype: int64

# %%
df['Age'].fillna('30',inplace=True)
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28      0
# 1                              Moen, Mr. Sigurd Hansen    male  25      0
# 2                               Jensen, Mr. Hans Peder    male  20      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29      0
# 4                               Davidson, Mr. Thornton    male  31      1
# ..                                                 ...     ...  ..    ...
# ...

# %%
ndf=df.drop('Cabin',axis=1)
ndf
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28      0
# 1                              Moen, Mr. Sigurd Hansen    male  25      0
# 2                               Jensen, Mr. Hans Peder    male  20      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29      0
# 4                               Davidson, Mr. Thornton    male  31      1
# ..                                                 ...     ...  ..    ...
# ...

# %%
print(ndf['Embarked'].value_counts())
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
ndf['Embarked'].fillna('S',inplace=True)
ndf
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28      0
# 1                              Moen, Mr. Sigurd Hansen    male  25      0
# 2                               Jensen, Mr. Hans Peder    male  20      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29      0
# 4                               Davidson, Mr. Thornton    male  31      1
# ..                                                 ...     ...  ..    ...
# ...

# %%
ndf.isnull().sum().sum()
# Out:
# 0
# 0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.boxplot(data=ndf)

# %%
from sklearn.preprocessing import StandardScaler
data1=ndf.copy()
scaler=StandardScaler()
data1['PassengerId']=scaler.fit_transform(ndf[['PassengerId']].values)
data1['Pclass']=scaler.fit_transform(ndf[['Pclass']].values)
data1['Age']=scaler.fit_transform(ndf[['Age']].values)
data1['SibSp']=scaler.fit_transform(ndf[['SibSp']].values)
data1['Parch']=scaler.fit_transform(ndf[['Parch']].values)
data1['Fare']=scaler.fit_transform(ndf[['Fare']].values)
sns.boxplot(data=data1)

# %%
g=sns.FacetGrid(ndf,'Sex', col='Survived')
g.map(sns.distplot, 'Age')
g.add_legend()

# %%
g=sns.FacetGrid(ndf,'Embarked', col='Survived')
g.map(sns.distplot, 'Fare')
g.add_legend()

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
data=ndf.copy()
data["Survived"]=encoder.fit_transform(ndf["Survived"])
data["Sex"]=encoder.fit_transform(ndf["Sex"])
data["Embarked"]=encoder.fit_transform(ndf["Embarked"])

# %%
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )

# %%
plot_correlation_map( ndf )

# %%
"""
Each cell in the grid represents the value of the correlation coefficient between two variables.
The value at position (a, b) represents the correlation coefficient between features at row a and column b. This will be equal to the value at position (b, a)
All diagonal elements are 1. Since diagonal elements represent the correlation of each variable with itself, it will always be equal to 1.
A large positive value (near to 1.0) indicates a strong positive correlation, i.e., if the value of one of the variables increases, the value of the other variable increases as well.
A large negative value (near to -1.0) indicates a strong negative correlation, i.e., the value of one variable decreases with the other’s increasing and vice-versa.
A value near to 0 (both positive or negative) indicates the absence of any correlation between the two variables, and hence those variables are independent of each other.
"""
# Out:
# '\nEach cell in the grid represents the value of the correlation coefficient between two variables.\nThe value at position (a, b) represents the correlation coefficient between features at row a and column b. This will be equal to the value at position (b, a)\nAll diagonal elements are 1. Since diagonal elements represent the correlation of each variable with itself, it will always be equal to 1.\nA large positive value (near to 1.0) indicates a strong positive correlation, i.e., if the value of one of the variables increases, the value of the other variable increases as well.\nA large negative value (near to -1.0) indicates a strong negative correlation, i.e., the value of one variable decreases with the other’s increasing and vice-versa.\nA value near to 0 (both positive or negative) indicates the absence of any correlation between the two variables, and hence those variables are independent of each other.\n'
# ...

# %%
data["Pclass"]=encoder.fit_transform(ndf["Pclass"])
data[['Pclass','Survived']].groupby(['Pclass'],as_index=True).mean()
# Out:
#         Survived
# Pclass
# 0       0.629630
# 1       0.472826
# 2       0.242363
#         Survived
# Pclass
# 0       0.629630
# 1       0.472826
# 2       0.242363

# %%
data['Title']=data.Name.str.extract('([A-Za-z]+)\.')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       1
# 1             76         0       2
# 2            641         0       2
# 3            568         0       2
# 4            672         0       0
# ..           ...       ...     ...
# 886           10         1       1
# 887           61         0       2
# 888          535         0       2
# 889          102         0       2
# 890          428         1       1
#
#                                                   Name  Sex Age  SibSp  Parch  \
# 0                           Collander, Mr. Erik Gustaf    1  28      0      0
# 1                              Moen, Mr. Sigurd Hansen    1  25      0      0
# 2                               Jensen, Mr. Hans Peder    1  20      0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29      0      4
# 4                               Davidson, Mr. Thornton    1  31      1      0
# ...

# %%
data3=data.copy()
data3["Title"]=encoder.fit_transform(data3["Title"])
data3
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       1
# 1             76         0       2
# 2            641         0       2
# 3            568         0       2
# 4            672         0       0
# ..           ...       ...     ...
# 886           10         1       1
# 887           61         0       2
# 888          535         0       2
# 889          102         0       2
# 890          428         1       1
#
#                                                   Name  Sex Age  SibSp  Parch  \
# 0                           Collander, Mr. Erik Gustaf    1  28      0      0
# 1                              Moen, Mr. Sigurd Hansen    1  25      0      0
# 2                               Jensen, Mr. Hans Peder    1  20      0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29      0      4
# 4                               Davidson, Mr. Thornton    1  31      1      0
# ...

# %%
plot_correlation_map( data.drop(['PassengerId','Name','Ticket'],axis=1) )

# %%
g=sns.FacetGrid(data,'Sex', col='Title')
g.map(sns.distplot, 'Age')
g.add_legend()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# ...

# %%
Dict = {"Capt":"Officer","Col":"Officer","Major":"Officer","Dr":"Officer","Rev":"Officer",
"Jonkheer": "Royalty","Don":"Royalty","Sir":"Royalty","Lady":"Royalty","the Countess":"Royalty","Dona":"Royalty",
 "Mme": "Miss", "Mlle":"Miss","Miss" :"Miss","Ms":"Mrs","Mr":"Mrs","Mrs" :"Mrs","Master":"Master" }

# %%
data['Title']=data['Title'].map(Dict)
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       1
# 1             76         0       2
# 2            641         0       2
# 3            568         0       2
# 4            672         0       0
# ..           ...       ...     ...
# 886           10         1       1
# 887           61         0       2
# 888          535         0       2
# 889          102         0       2
# 890          428         1       1
#
#                                                   Name  Sex Age  SibSp  Parch  \
# 0                           Collander, Mr. Erik Gustaf    1  28      0      0
# 1                              Moen, Mr. Sigurd Hansen    1  25      0      0
# 2                               Jensen, Mr. Hans Peder    1  20      0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29      0      4
# 4                               Davidson, Mr. Thornton    1  31      1      0
# ...

# %%
g=sns.FacetGrid(data,'Sex', col='Title')
g.map(sns.distplot, 'Age')
g.add_legend()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %%
data['FamilySize']=data.apply(lambda row: row.SibSp + row.Parch, axis=1)
data=data.drop(['SibSp','Parch'],axis=1)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       1
# 1             76         0       2
# 2            641         0       2
# 3            568         0       2
# 4            672         0       0
# ..           ...       ...     ...
# 886           10         1       1
# 887           61         0       2
# 888          535         0       2
# 889          102         0       2
# 890          428         1       1
#
#                                                   Name  Sex Age      Ticket  \
# 0                           Collander, Mr. Erik Gustaf    1  28      248740
# 1                              Moen, Mr. Sigurd Hansen    1  25      348123
# 2                               Jensen, Mr. Hans Peder    1  20      350050
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29      349909
# 4                               Davidson, Mr. Thornton    1  31  F.C. 12750
# ..                                                 ...  ...  ..         ...
# ...

# %%
data[['FamilySize','Survived']].groupby(['FamilySize'],as_index=True).mean()
# Out:
#             Survived
# FamilySize
# 0           0.303538
# 1           0.552795
# 2           0.578431
# 3           0.724138
# 4           0.200000
# 5           0.136364
# 6           0.333333
# 7           0.000000
# 10          0.000000
#             Survived
# FamilySize
# 0           0.303538
# 1           0.552795
# 2           0.578431
# 3           0.724138
# 4           0.200000
# 5           0.136364
# 6           0.333333
# 7           0.000000
# 10          0.000000

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass                                         Name  \
# 0          343         0       1                   Collander, Mr. Erik Gustaf
# 1           76         0       2                      Moen, Mr. Sigurd Hansen
# 2          641         0       2                       Jensen, Mr. Hans Peder
# 3          568         0       2  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672         0       0                       Davidson, Mr. Thornton
#
#    Sex Age      Ticket     Fare  Embarked Title  FamilySize
# 0    1  28      248740  13.0000         2   Mrs           0
# 1    1  25      348123   7.6500         2   Mrs           0
# 2    1  20      350050   7.8542         2   Mrs           0
# 3    0  29      349909  21.0750         2   Mrs           4
# 4    1  31  F.C. 12750  52.0000         2   Mrs           1
#    PassengerId  Survived  Pclass                                         Name  \
# ...

# %%
#import relevant libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

#features extraction
x=data.drop(['Survived','PassengerId','Name','Title','Ticket'],axis=1)
y=data["Survived"]

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=40) #splitting data with test size of 35%

logreg = LogisticRegression()   #build our logistic model
logreg.fit(x_train, y_train)  #fitting training data
y_pred  = logreg.predict(x_test)    #testing model’s performance
print("Accuracy={:.2f}".format(logreg.score(x_test, y_test)))
# Out:
# Accuracy=0.80
# Accuracy=0.80

# %%
confusion_matrix=pd.crosstab(y_test,y_pred,rownames=['Actual'],colnames=['Predicted'])
print(confusion_matrix)
# Out:
# Predicted    0   1
# Actual
# 0          161  28
# 1           34  89
# Predicted    0   1
# Actual
# 0          161  28
# 1           34  89

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84       189
#            1       0.76      0.72      0.74       123
#
#     accuracy                           0.80       312
#    macro avg       0.79      0.79      0.79       312
# weighted avg       0.80      0.80      0.80       312
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84       189
#            1       0.76      0.72      0.74       123
#
#     accuracy                           0.80       312
#    macro avg       0.79      0.79      0.79       312
# weighted avg       0.80      0.80      0.80       312

# %%
import sklearn.metrics as metrics
probs = logreg.predict_proba(x_test)
preds = probs[:,1]
fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
roc_auc = metrics.auc(fpr, tpr)

import matplotlib.pyplot as plt
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

from ggplot import *
df = pd.DataFrame(dict(fpr = fpr, tpr = tpr))
ggplot(df, aes(x = 'fpr', y = 'tpr')) + geom_line() + geom_abline(linetype = 'dashed')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-68-b7f0f4236e47> in <module>
#      16 plt.show()
#      17
# ---> 18 from ggplot import *
#      19 df = pd.DataFrame(dict(fpr = fpr, tpr = tpr))
#      20 ggplot(df, aes(x = 'fpr', y = 'tpr')) + geom_line() + geom_abline(linetype = 'dashed')
#
# ModuleNotFoundError: No module named 'ggplot'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-68-b7f0f4236e47> in <module>
#      16 plt.show()
#      17
# ---> 18 from ggplot import *
#      19 df = pd.DataFrame(dict(fpr = fpr, tpr = tpr))
#      20 ggplot(df, aes(x = 'fpr', y = 'tpr')) + geom_line() + geom_abline(linetype = 'dashed')
#
# ModuleNotFoundError: No module named 'ggplot'

# %%
'''An excellent model has AUC near to the 1 which means it has good measure of separability. A poor model has AUC near to the 0 which means it has worst measure of separability. In fact it means it is reciprocating the result. It is predicting 0s as 1s and 1s as 0s. And when AUC is 0.5, it means model has no class separation capacity whatsoever.'''
# Out:
# 'An excellent model has AUC near to the 1 which means it has good measure of separability. A poor model has AUC near to the 0 which means it has worst measure of separability. In fact it means it is reciprocating the result. It is predicting 0s as 1s and 1s as 0s. And when AUC is 0.5, it means model has no class separation capacity whatsoever.'
# 'An excellent model has AUC near to the 1 which means it has good measure of separability. A poor model has AUC near to the 0 which means it has worst measure of separability. In fact it means it is reciprocating the result. It is predicting 0s as 1s and 1s as 0s. And when AUC is 0.5, it means model has no class separation capacity whatsoever.'

# %%
'''When AUC is 0.7, it means there is 70% chance that model will be able to distinguish between positive class and negative class.
'''
# Out:
# 'When AUC is 0.7, it means there is 70% chance that model will be able to distinguish between positive class and negative class.\n'
# 'When AUC is 0.7, it means there is 70% chance that model will be able to distinguish between positive class and negative class.\n'
